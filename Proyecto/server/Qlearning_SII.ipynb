# %% [markdown]
# # Problema de Markov basado en la persona con SII #
#
# Se crea un problema d emarkov ajustado al ambiente de la persona que consume ciertos alimentos y presenta ciertos sintomas

# %%
from collections import defaultdict
from utils import argmax
from mdp import MDP, policy_evaluation
from bayesianFood_lite import *
from pgmpy.sampling import BayesianModelSampling


class PersonFoodAndSympthonsMDP(MDP):
    def __init__(self, model, actlist, terminals, reward=None, states=None, gamma=0.9):
        if not (0 < gamma <= 1):
            raise ValueError("An MDP must have 0 < gamma <= 1")
        #bayesian model
        self.model= model
        #symptoms list
        sintomas=pd.read_csv("sintomas.csv", delimiter=';')
        # states
        self.states = states
        ## initial state
        inference = BayesianModelSampling(model)
        initial=inference.forward_sample()
        init=[]
        for b in sintomas['symptom']:
            for a in list(initial):
                if(a==b):
                    init.append((b,initial.iloc[0][a]))
        self.init = tuple(init)
        #actions
        self.actlist = actlist       
        self.terminals = terminals

        self.gamma = gamma

        self.reward = reward or {s: 0 for s in self.states}
    def calculate_reward(self,state):
        aux=0
        for (s,l) in state:
            aux=aux+l
        
        reward=(1/len(state))+1/aux
        return reward

    def getNextState(self, a):
        print ("obteniendo siguiente estado")
        evidence = a
        week=inference.likelihood_weighted_sample(evidence=evidence, size=1)
        status=[]
        foods=[]
        for a in list(week):
            for b in sintomas['symptom']:
                if(a==b):
                    status.append((a,week.iloc[0][a]))
        self.reward[status]=calculate_reward(status)
        print (status)       
        return status
# Out:
# Traceback (most recent call last):
#
#   File "/home/mruizh/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2910, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-10-395d12b7aadb>", line 4, in <module>
#     from bayesianFood_lite import *
#
#   File "/home/mruizh/proyecto/bayesianFood_lite.py", line 112
#     cpd_sintDisp = TabularCPD(variable='sintomasDispepsicos', variable_card=3,
#                                                                               ^
# IndentationError: unindent does not match any outer indentation level

# %%
class QLearningAgent:
    """ An exploratory Q-learning agent """
    def __init__(self, mdp, Ne, Rplus, alpha=None):

        self.gamma = mdp.gamma
        self.terminals = mdp.terminals
        self.all_act = mdp.actlist
        self.Ne = Ne  # iteration limit in exploration function
        self.Rplus = Rplus  # large value to assign before iteration limit
        self.Q = defaultdict(float)
        self.Nsa = defaultdict(float)
        self.s = None
        self.a = None
        self.r = None

        if alpha:
            self.alpha = alpha
        else:
            self.alpha = lambda n: 1./(1+n)  # udacity video

    def f(self, u, n):
        """ Exploration function. Returns fixed Rplus until
        agent has visited state, action a Ne number of times.
        Same as ADP agent in book."""
        if n < self.Ne:
            return self.Rplus
        else:
            return u

    def actions_in_state(self, state):
        """ Return actions possible in given state.
            Useful for max and argmax. """
        if state in self.terminals:
            return [None]
        else:
            return self.all_act

    def __call__(self, percept):
        s1, r1 = self.update_state(percept)
        Q, Nsa, s, a, r = self.Q, self.Nsa, self.s, self.a, self.r
        alpha, gamma, terminals = self.alpha, self.gamma, self.terminals,
        actions_in_state = self.actions_in_state

        if s in terminals:
            Q[s, None] = r1
        if s is not None:
            Nsa[s, a] += 1
            Q[s, a] += alpha(Nsa[s, a]) * (r + gamma * max(Q[s1, a1]
                                           for a1 in actions_in_state(s1)) - Q[s, a])
        if s in terminals:
            self.s = self.a = self.r = None
        else:
            self.s, self.r = s1, r1
            self.a = argmax(actions_in_state(s1), key=lambda a1: self.f(Q[s1, a1], Nsa[s1, a1]))
        return self.a

    def update_state(self, percept):
        """To be overridden in most cases. The default case
        assumes the percept to be of type (state, reward)."""
        return percept


def run_single_trial(agent_program, mdp):
    """Execute trial for given agent_program
    and mdp. mdp should be an instance of subclass
    of mdp.MDP """

    def take_single_action(mdp, s, a):
        """
        Get the next state with the action selected
        """
        state= mdp.getNextState(a)

        return state

    current_state = mdp.init
    while True:
        current_reward = mdp.R(current_state)
        percept = (current_state, current_reward)
        next_action = agent_program(percept)
        if next_action is None:
            break
        current_state = take_single_action(mdp, current_state, next_action)

# %% [markdown]
# Probamos el entorno

# %%
import pickle
pickled_file = open('sintomas.p','rb')
u=pickle.Unpickler(pickled_file)
states = u.load()
states
# Out:
# [(('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 1),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 0),
#   ('reflujoGastroesofagico', 0),
# ...
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 1),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 0),
#   ('sintomasDispepsicos', 2),
#   ('diarrea', 2),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 0),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 1),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 0),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 1),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 0)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 1)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 0),
#   ('estrenimiento', 2),
#   ('intolerancia', 2),
#   ('borborigmos', 2)),
#  (('distensionAbdominal', 0),
#   ('flatulencia', 0),
#   ('dolorAbdominal', 1),
#   ('reflujoGastroesofagico', 1),
#   ('sintomasDispepsicos', 0),
#   ('diarrea', 1),
#   ('estrenimiento', 0),
#   ('intolerancia', 0),
#   ('borborigmos', 0)),
#  ...]

# %%
states[0]
# Out:
# (('distensionAbdominal', 0),
#  ('flatulencia', 0),
#  ('dolorAbdominal', 0),
#  ('reflujoGastroesofagico', 0),
#  ('sintomasDispepsicos', 0),
#  ('diarrea', 0),
#  ('estrenimiento', 0),
#  ('intolerancia', 0),
#  ('borborigmos', 0))

# %%
import pickle
pickled_file = open('alimentos_lite.p','rb')
u=pickle.Unpickler(pickled_file)
actlist = u.load()

# %%
#symptoms list
sintomas=pd.read_csv("sintomas.csv", delimiter=';')
terminals=[]
terminal=[]
for s in sintomas['symptom']:
    terminal.append((s,0))
terminals.append(terminal)
i=0
for s in sintomas['symptom']:
    terminaln=terminal.copy()
    terminaln[i]=(s,1)
    i+=1
    terminals.append(terminaln)
terminals
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f1c72d7c9314> in <module>()
#       1 #symptoms list
# ----> 2 sintomas=pd.read_csv("sintomas.csv", delimiter=';')
#       3 terminals=[]
#       4 terminal=[]
#       5 for s in sintomas['symptom']:
#
# NameError: name 'pd' is not defined

# %%
model= create_model()

# %%
mdpPerson= PersonFoodAndSympthonsMDP(model, actlist=actlist, states=states, terminals=terminals)

# %%
mdpPerson.init

# %%
agent_Qlearn=QLearningAgent(mdpPerson, 5, 2, alpha=0.5)

# %%
run_single_trial(agent_Qlearn, mdpPerson)
